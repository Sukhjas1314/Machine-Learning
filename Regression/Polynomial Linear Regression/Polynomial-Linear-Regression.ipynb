# %% [markdown]
# # Polynomial Linear Regression

# %% [markdown]
# ### Dataset Preprocessing

# %% [markdown]
# ##### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Importing Datasets

# %%
df = pd.read_csv("Position_Salaries.csv")
X = df.iloc[:,1:-1].values
y = df.iloc[:,-1].values

# %% [markdown]
# ##### Training Linear Regression model on the whole Dataset

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# ##### Training Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
lr2 = LinearRegression()
lr2.fit(X_poly,y)
# Out:
# LinearRegression()

# %% [markdown]
# ##### Visualising Linear regression results

# %%
plt.scatter(X,y,color = "red")
plt.plot(X,lr.predict(X),color = "blue")
plt.title("Truth or Bluff (Linear Regression)")
plt.xlabel("Position level")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ##### Visualising Polynomial regression results

# %%
plt.scatter(X,y,color = "red")
plt.plot(X,lr2.predict(poly_reg.fit_transform(X)),color = "blue")
plt.title("Truth or Bluff (Polynomial Regression)")
plt.xlabel("Position level")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ##### Visualising Polynomial regression results (for higher resolution and smoother curves)

# %%
X_grid = np.arange(min(X),max(X),0.1)
X_grid = X_grid.reshape((len(X_grid),1))
plt.scatter(X,y,color = "red")
plt.plot(X_grid,lr2.predict(poly_reg.fit_transform(X_grid)),color = "blue")
plt.title("Truth or Bluff (Polynomial Regression)")
plt.xlabel("Position level")
plt.ylabel("Salary")
plt.show()
# Out:
# /var/folders/9f/3bvh2cpx00q65vmntbjg24v00000gn/T/ipykernel_41922/1610313752.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X),max(X),0.1)

# %% [markdown]
# ##### Predicting new result with Linear Regression

# %%
print(lr.predict([[6.5]]))
# Out:
# [330378.78787879]

# %% [markdown]
# ##### Predicting new result with Polynomial Regression

# %%
print(lr2.predict(poly_reg.fit_transform([[6.5]])))
# Out:
# [158862.45265153]
